# %% [markdown]
# We now want to analyze the emotion context of the books.
# For example, if you want an exciting read -- we want to use the descriptions to determine suspensefulness

# %% [markdown]
# We will have 7 categories:
# Anger, disgust, fear, joy, sadness, surprise, neutral

# %% [markdown]
# We will be fine-tuning our model for sentiment analysis on LLMS

# %% [markdown]
# # What is Fine-Tuning?

# %% [markdown]
# 1. We take a pre-trained LLM model.
# 2. Instead of taking a pre-trained LLM, we train it further on a dataset. This helps refine the weights and parameters, allowing the model to "specialize" in a task

# %% [markdown]
# We are going to use a model from hugging face that has been finetuned

# %%
from transformers import AutoModelForSequenceClassification, AutoTokenizer, pipeline
model_name = "j-hartmann/emotion-english-distilroberta-base"
bart_model = AutoModelForSequenceClassification.from_pretrained(model_name)
bart_tokenizer = AutoTokenizer.from_pretrained(model_name)

classifier = pipeline(
    "text-classification",
    model = model_name,
    top_k = None,
    device = "mps"
)
classifier("I love this")
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/huggingface_hub/file_download.py:896: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# [[{'label': 'joy', 'score': 0.9845667481422424},
#   {'label': 'surprise', 'score': 0.004927205853164196},
#   {'label': 'sadness', 'score': 0.004531427752226591},
#   {'label': 'neutral', 'score': 0.003475314239040017},
#   {'label': 'anger', 'score': 0.0013875315198674798},
#   {'label': 'disgust', 'score': 0.0007134051411412656},
#   {'label': 'fear', 'score': 0.0003984911891166121}]]

# %%
import pandas as pd
books = pd.read_csv("/Users/naomigong/Coding/Book_Recommender/final_data_set.csv")

# %%
import textwrap

# Get the first book description
desc = books["description"][0]

# Wrap the text at 80 characters per line
wrapped_text = textwrap.fill(desc, width=80)

# Print it so it displays over multiple lines
print(wrapped_text)
# Out:
# A NOVEL THAT READERS and critics have been eagerly anticipating for over a
# decade, Gilead is an astonishingly imagined story of remarkable lives. John Ames
# is a preacher, the son of a preacher and the grandson (both maternal and
# paternal) of preachers. It’s 1956 in Gilead, Iowa, towards the end of the
# Reverend Ames’s life, and he is absorbed in recording his family’s story, a
# legacy for the young son he will never see grow up. Haunted by his grandfather’s
# presence, John tells of the rift between his grandfather and his father: the
# elder, an angry visionary who fought for the abolitionist cause, and his son, an
# ardent pacifist. He is troubled, too, by his prodigal namesake, Jack (John Ames)
# Boughton, his best friend’s lost son who returns to Gilead searching for
# forgiveness and redemption. Told in John Ames’s joyous, rambling voice that
# finds beauty, humour and truth in the smallest of life’s details, Gilead is a
# song of celebration and acceptance of the best and the worst the world has to
# offer. At its heart is a tale of the sacred bonds between fathers and sons,
# pitch-perfect in style and story, set to dazzle critics and readers alike.

# %%
classifier(desc)
# Out:
# [[{'label': 'fear', 'score': 0.6548418402671814},
#   {'label': 'neutral', 'score': 0.1698518544435501},
#   {'label': 'sadness', 'score': 0.11640852689743042},
#   {'label': 'surprise', 'score': 0.020700614899396896},
#   {'label': 'disgust', 'score': 0.01910070702433586},
#   {'label': 'joy', 'score': 0.01516131404787302},
#   {'label': 'anger', 'score': 0.003935142420232296}]]

# %% [markdown]
# Here, we get that it is 65% chance it is fear, but from we are reading it seems to be more of joy. We don't really get fear from it.
#
# We want to capture the different emotions and themes

# %%
classifier(books["description"][0].split("."))
# Out:
# [[{'label': 'surprise', 'score': 0.7296029925346375},
#   {'label': 'neutral', 'score': 0.1403854638338089},
#   {'label': 'fear', 'score': 0.06816218048334122},
#   {'label': 'joy', 'score': 0.04794241860508919},
#   {'label': 'anger', 'score': 0.009156342595815659},
#   {'label': 'disgust', 'score': 0.002628472400829196},
#   {'label': 'sadness', 'score': 0.002122160280123353}],
#  [{'label': 'neutral', 'score': 0.4493720233440399},
#   {'label': 'disgust', 'score': 0.27359044551849365},
#   {'label': 'joy', 'score': 0.10908288508653641},
#   {'label': 'sadness', 'score': 0.09362718462944031},
#   {'label': 'anger', 'score': 0.0404781699180603},
#   {'label': 'surprise', 'score': 0.026970194652676582},
#   {'label': 'fear', 'score': 0.006879037246108055}],
#  [{'label': 'neutral', 'score': 0.6462165713310242},
#   {'label': 'sadness', 'score': 0.2427329570055008},
#   {'label': 'disgust', 'score': 0.04342255741357803},
#   {'label': 'surprise', 'score': 0.028300538659095764},
#   {'label': 'joy', 'score': 0.014211433939635754},
#   {'label': 'fear', 'score': 0.01408409047871828},
#   {'label': 'anger', 'score': 0.01103187631815672}],
#  [{'label': 'fear', 'score': 0.9281687140464783},
#   {'label': 'anger', 'score': 0.03219057247042656},
#   {'label': 'neutral', 'score': 0.012808623723685741},
#   {'label': 'sadness', 'score': 0.008756824769079685},
#   {'label': 'surprise', 'score': 0.00859786756336689},
#   {'label': 'disgust', 'score': 0.008431775495409966},
#   {'label': 'joy', 'score': 0.001045578857883811}],
#  [{'label': 'sadness', 'score': 0.9671575427055359},
#   {'label': 'neutral', 'score': 0.015104156918823719},
#   {'label': 'disgust', 'score': 0.006480592768639326},
#   {'label': 'fear', 'score': 0.005393992643803358},
#   {'label': 'surprise', 'score': 0.0022869419772177935},
#   {'label': 'anger', 'score': 0.0018428867915645242},
#   {'label': 'joy', 'score': 0.0017338788602501154}],
#  [{'label': 'joy', 'score': 0.932797908782959},
#   {'label': 'disgust', 'score': 0.037717171013355255},
#   {'label': 'neutral', 'score': 0.015891853719949722},
#   {'label': 'sadness', 'score': 0.006444492843002081},
#   {'label': 'anger', 'score': 0.00502497935667634},
#   {'label': 'surprise', 'score': 0.0015812070341780782},
#   {'label': 'fear', 'score': 0.0005423070979304612}],
#  [{'label': 'joy', 'score': 0.6528702974319458},
#   {'label': 'neutral', 'score': 0.25427499413490295},
#   {'label': 'surprise', 'score': 0.06808311492204666},
#   {'label': 'sadness', 'score': 0.009909006766974926},
#   {'label': 'disgust', 'score': 0.006512214429676533},
#   {'label': 'anger', 'score': 0.004821307957172394},
#   {'label': 'fear', 'score': 0.003529021516442299}],
#  [{'label': 'neutral', 'score': 0.5494773387908936},
#   {'label': 'sadness', 'score': 0.11169011145830154},
#   {'label': 'disgust', 'score': 0.1040065661072731},
#   {'label': 'surprise', 'score': 0.07876542210578918},
#   {'label': 'anger', 'score': 0.06413352489471436},
#   {'label': 'fear', 'score': 0.051362715661525726},
#   {'label': 'joy', 'score': 0.04056432843208313}]]

# %% [markdown]
# Proposal: For each book, have a different column for each emotion classes. Instead of giving one emotion, take the highest probability for each emotion across the entire description.

# %%
#extract the max prediction for each emotion for each description
emotion_labels = ["anger", "disgust", "joy", "sadness", "surprise", "neutral"]
isbn = []
import numpy as np
#this will help create a dataframe, where the label (emotion) corresponds with the max prediction of the label among all sentences in a descrption
emotions_score = {label : [] for label in emotion_labels}
def calculate_max_emotion_score(predictions):
    per_emotion_score = {label : [] for label in emotion_labels}
    for prediction in predictions:
        sorted_predictions = sorted(prediction, key=lambda x: x["label"])
        for index, label in enumerate(emotion_labels):
            #sorted_predictions[index] indexes into the array, which holds hashmaps
            #Then get the value assorted with key score
            per_emotion_score[label].append(sorted_predictions[index]["score"])
    return {label: np.max(score) for label, score in per_emotion_score.items()}

# %%
pred = classifier(books["description"][0].split("."))
calculate_max_emotion_score(pred)
# Out:
# {'anger': 0.06413352489471436,
#  'disgust': 0.27359044551849365,
#  'joy': 0.9281687140464783,
#  'sadness': 0.932797908782959,
#  'surprise': 0.6462165713310242,
#  'neutral': 0.9671575427055359}

# %%
for i in range(10):
    isbn.append(books["isbn13"][i])
    #split up the sentence for the current description
    sentences = books["description"][i].split(".")
    predictions = classifier(sentences)
    max_scores = calculate_max_emotion_score(predictions)
    for label in emotion_labels:
        emotions_score[label].append(max_scores[label])

# %%
emotions_score
# Out:
# {'anger': [0.06413352489471436,
#   0.6126187443733215,
#   0.06413352489471436,
#   0.3514840602874756,
#   0.08141219615936279,
#   0.23222504556179047,
#   0.5381841659545898,
#   0.06413352489471436,
#   0.30067068338394165,
#   0.06413352489471436],
#  'disgust': [0.27359044551849365,
#   0.3482857048511505,
#   0.1040065661072731,
#   0.15072256326675415,
#   0.18449510633945465,
#   0.7271746397018433,
#   0.1558549553155899,
#   0.1040065661072731,
#   0.2794807553291321,
#   0.17792753875255585],
#  'joy': [0.9281687140464783,
#   0.9425276517868042,
#   0.9723208546638489,
#   0.36070626974105835,
#   0.09504330158233643,
#   0.051362715661525726,
#   0.7474279999732971,
#   0.4044966399669647,
#   0.9155241250991821,
#   0.051362715661525726],
#  'sadness': [0.932797908782959,
#   0.7044218182563782,
#   0.7672365307807922,
#   0.251880943775177,
#   0.04056432843208313,
#   0.04337584972381592,
#   0.8725653886795044,
#   0.04056432843208313,
#   0.04056432843208313,
#   0.04056432843208313],
#  'surprise': [0.6462165713310242,
#   0.8879396319389343,
#   0.5494773387908936,
#   0.7326858043670654,
#   0.8843892216682434,
#   0.6213927268981934,
#   0.7121946215629578,
#   0.5494773387908936,
#   0.8402897119522095,
#   0.8603722453117371],
#  'neutral': [0.9671575427055359,
#   0.11169011145830154,
#   0.11169011145830154,
#   0.11169011145830154,
#   0.4758807420730591,
#   0.11169011145830154,
#   0.4080001413822174,
#   0.8202824592590332,
#   0.35445934534072876,
#   0.11169011145830154]}

# %%
from tqdm import tqdm

emotion_labels = ["anger", "disgust", "joy", "sadness", "surprise", "neutral"]
isbn = []
import numpy as np
#this will help create a dataframe, where the label (emotion) corresponds with the max prediction of the label among all sentences in a descrption
emotions_score = {label : [] for label in emotion_labels}

for i in tqdm(range(len(books))):
    isbn.append(books["isbn13"][i])
    #split up the sentence for the current description
    sentences = books["description"][i].split(".")
    predictions = classifier(sentences)
    max_scores = calculate_max_emotion_score(predictions)
    for label in emotion_labels:
        emotions_score[label].append(max_scores[label])
# Out:
# 100%|██████████| 5693/5693 [05:18<00:00, 17.85it/s]

# %% [markdown]
# Now, create new dataframe with emotions as columns

# %%
books = pd.read_csv("final_data_set.csv")

# %%
emotions_df = pd.DataFrame(emotions_score) #emotions is a dictionary with label as the emotion name
emotions_df["isbn13"] = isbn
books = pd.merge(books, emotions_df, on="isbn13")
books.drop(columns="Unnamed: 0")
# Out:
#              isbn13      isbn10  \
# 0     9780002005883  0002005883
# 1     9780002261982  0002261987
# 2     9780006178736  0006178731
# 3     9780006280897  0006280897
# 4     9780006280934  0006280935
# ...             ...         ...
# 5688  9788173031014  8173031010
# 5689  9788179921623  817992162X
# 5690  9788185300535  8185300534
# 5691  9789027712059  9027712050
# 5692  9789042003408  9042003405
#
#                                                   title  \
# 0                                                Gilead
# 1                                          Spider's Web
# 2                                        Rage of angels
# 3                                        The Four Loves
# 4                                   The Problem of Pain
# ...                                                 ...
# 5688                                Journey to the East
# 5689  The Monk Who Sold His Ferrari: A Fable About F...
# 5690                                          I Am that
# 5691                           The Berlin Phenomenology
# 5692                          'I'm Telling You Stories'
#
#                                            authors  \
# 0                               Marilynne Robinson
# 1                  Charles Osborne;Agatha Christie
# 2                                   Sidney Sheldon
# 3                              Clive Staples Lewis
# 4                              Clive Staples Lewis
# ...                                            ...
# 5688                                 Hermann Hesse
# 5689                                  Robin Sharma
# 5690  Sri Nisargadatta Maharaj;Sudhakar S. Dikshit
# 5691                 Georg Wilhelm Friedrich Hegel
# 5692                        Helena Grice;Tim Woods
#
#                          categories  \
# 0                           Fiction
# 1     Detective and mystery stories
# 2                           Fiction
# 3                    Christian life
# 4                    Christian life
# ...                             ...
# 5688              Adventure stories
# 5689               Health & Fitness
# 5690                     Philosophy
# 5691                        History
# 5692             Literary Criticism
#
#                                               thumbnail  \
# 0     http://books.google.com/books/content?id=KQZCP...
# 1     http://books.google.com/books/content?id=gA5GP...
# 2     http://books.google.com/books/content?id=FKo2T...
# 3     http://books.google.com/books/content?id=XhQ5X...
# 4     http://books.google.com/books/content?id=Kk-uV...
# ...                                                 ...
# 5688  http://books.google.com/books/content?id=rq6JP...
# 5689  http://books.google.com/books/content?id=c_7mf...
# 5690  http://books.google.com/books/content?id=Fv_JP...
# 5691  http://books.google.com/books/content?id=Vy7Sk...
# 5692  http://books.google.com/books/content?id=2lVyR...
#
#                                             description  published_year  \
# 0     A NOVEL THAT READERS and critics have been eag...          2004.0
# 1     A new 'Christie for Christmas' -- a full-lengt...          2000.0
# 2     A memorable, mesmerizing heroine Jennifer -- b...          1993.0
# 3     Lewis' work on the nature of love divides love...          2002.0
# 4     "In The Problem of Pain, C.S. Lewis, one of th...          2002.0
# ...                                                 ...             ...
# 5688  This book tells the tale of a man who goes on ...          2002.0
# 5689  Wisdom to Create a Life of Passion, Purpose, a...          2003.0
# 5690  This collection of the timeless teachings of o...          1999.0
# 5691  Since the three volume edition ofHegel's Philo...          1981.0
# 5692  This is a jubilant and rewarding collection of...          1998.0
#
#       average_rating  num_pages  ...     joy_x sadness_x surprise_x neutral_x  \
# 0               3.85      247.0  ...  0.928169  0.932798   0.646217  0.967158
# 1               3.83      241.0  ...  0.942528  0.704422   0.887940  0.111690
# 2               3.93      512.0  ...  0.972321  0.767237   0.549477  0.111690
# 3               4.15      170.0  ...  0.360706  0.251881   0.732686  0.111690
# 4               4.09      176.0  ...  0.095043  0.040564   0.884389  0.475881
# ...              ...        ...  ...       ...       ...        ...       ...
# 5688            3.70      175.0  ...  0.051363  0.400263   0.883198  0.111690
# 5689            3.82      198.0  ...  0.339217  0.947779   0.375756  0.066685
# 5690            4.51      531.0  ...  0.459269  0.759456   0.951104  0.368110
# 5691            0.00      210.0  ...  0.051363  0.958549   0.915193  0.111690
# 5692            3.70      136.0  ...  0.051363  0.991484   0.549477  0.111690
#
#        anger_y disgust_y     joy_y  sadness_y  surprise_y  neutral_y
# 0     0.064134  0.273590  0.928169   0.932798    0.646217   0.967158
# 1     0.612619  0.348286  0.942528   0.704422    0.887940   0.111690
# 2     0.064134  0.104007  0.972321   0.767237    0.549477   0.111690
# 3     0.351484  0.150723  0.360706   0.251881    0.732686   0.111690
# 4     0.081412  0.184495  0.095043   0.040564    0.884389   0.475881
# ...        ...       ...       ...        ...         ...        ...
# 5688  0.064134  0.114383  0.051363   0.400263    0.883198   0.111690
# 5689  0.009997  0.009929  0.339217   0.947779    0.375756   0.066685
# 5690  0.064134  0.104007  0.459269   0.759456    0.951104   0.368110
# 5691  0.064134  0.104007  0.051363   0.958549    0.915193   0.111690
# 5692  0.064134  0.104007  0.051363   0.991484    0.549477   0.111690
#
# [5693 rows x 28 columns]

# %%
books.to_csv("books_with_emotion.csv", index = False)

# %%
books.columns
# Out:
# Index(['Unnamed: 0', 'isbn13', 'isbn10', 'title', 'authors', 'categories',
#        'thumbnail', 'description', 'published_year', 'average_rating',
#        'num_pages', 'ratings_count', 'title_and_subtitle',
#        'tagged_description', 'simplifed_categories', 'missing_cat_preds_x',
#        'missing_cat_preds_y', 'anger_x', 'disgust_x', 'joy_x', 'sadness_x',
#        'surprise_x', 'neutral_x', 'anger_y', 'disgust_y', 'joy_y', 'sadness_y',
#        'surprise_y', 'neutral_y'],
#       dtype='object')
